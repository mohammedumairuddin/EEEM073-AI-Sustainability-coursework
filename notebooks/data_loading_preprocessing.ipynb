# %%
# !git clone https://github.com/mohammedumairuddin/EEEM073-AI-Sustainability-coursework.git
# Out:
# Cloning into 'EEEM073-AI-Sustainability-coursework'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 62 (delta 11), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 2.04 MiB | 3.08 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
import os
os.getcwd()
# !ls
# Out:
# crop_production.csv  EEEM073-AI-Sustainability-coursework

# %%
cd EEEM073-AI-Sustainability-coursework/
# Out:
# /content/EEEM073-AI-Sustainability-coursework/datasets/EEEM073-AI-Sustainability-coursework

# %%
# !ls
# Out:
# datasets  models  notebooks  README.md	requirements.txt  results

# %%
# %cd datasets
# Out:
# /content/EEEM073-AI-Sustainability-coursework/datasets/EEEM073-AI-Sustainability-coursework/datasets

# %%
# !ls
# Out:
# crop_production.csv

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("crop_production.csv")
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
import numpy as np
df["Yield"] = df["Production"] / df["Area"]
df = df.replace([np.inf, -np.inf], np.nan)

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

categorical_columns = ["State_Name","District_Name","Season","Crop"]

for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# %%
import os

# Create the 'data' directory if it doesn't already exist
os.makedirs('data', exist_ok=True)
df.to_csv('data/processed_dataset.csv', index=False)
